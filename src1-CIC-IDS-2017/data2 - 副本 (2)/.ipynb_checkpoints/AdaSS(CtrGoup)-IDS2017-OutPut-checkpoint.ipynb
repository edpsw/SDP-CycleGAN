# %%
import numpy as np 
from pandas_ml import ConfusionMatrix

# %%
import pandas as pd
from sklearn.metrics import roc_auc_score
  
def Sensitivity(TP,FN):
    sen = TP/(TP + FN)
    return sen

def Specificity(TN,FP):
    spe = TN/(TN + FP)
    return spe

def GMean(sen,spe):
    return (sen * spe) ** 0.5

def FPR(FP,TN):
    return FP/(FP + TN)
  
def Precision(TP, TN, P):
    return (TP + TN) / P
    
def Balance(fpr, pre):
    return 1 - ((fpr**2 + (1-pre)**2)/2) ** 2
    
def AUC(y_true, y_pred):
    return roc_auc_score(y_true, y_pred)

def ACC(TP,TN,P):
    return (TP+TN)/P

def TPR(TP,FN):
    return TP/(TP+FN)

def F1(pre,tpr):
    return 2 * pre * tpr / (pre + tpr)
    
def MyMetrics(cm):
    tab = pd.crosstab(cm._y_true, cm._y_pred)
    TN = tab.reindex()[0][0]
    TP = tab.reindex()[1][1]
    FN = tab.reindex()[0][1]
    FP = tab.reindex()[1][0]
    P = cm.population
    sen = Sensitivity(TP,FN)
    spe = Specificity(TN,FP)
    fpr = FPR(FP,TN)
    pre = Precision(TP, TN, P)
    tpr = TPR(TP,FN)
    acc = ACC(TP,TN,P)
    f1 = F1(pre,tpr)
    
    gmean = GMean(sen,spe)
    balance = Balance(fpr, pre)
    auc = AUC(cm._y_true, cm._y_pred)
    print("FPR:",fpr)
    print("Precision:",pre)
    print("Accuracy:",acc)
    print("TPR:",tpr)
    print("F1_score:",f1)
    
    print("Sensitivity:",sen)
    print("Specificity:",spe)
    print("G-Mean:",gmean)
    print("Balance:", balance)
    print("AUC:", auc)

# %%
expected = np.loadtxt("EXP.txt") 
expected2 = np.loadtxt("EXP2.txt")

# %%
predicted4 = np.loadtxt("EE.txt") 
cm4 = ConfusionMatrix(expected, predicted4)
MyMetrics(cm4)
cm4
# Out:
# FPR: 0.30711620398549766
# Precision: 0.6908752815462783
# Accuracy: 0.6908752815462783
# TPR: 0.49873417721518987
# F1_score: 0.5792877865295875
# Sensitivity: 0.49873417721518987
# Specificity: 0.6928837960145023
# G-Mean: 0.587847624738784
# Balance: 0.9909865431472537
# AUC: 0.595808986614846
# Predicted  False   True  __all__
# Actual
# False      26182  11605    37787
# True         198    197      395
# __all__    26380  11802    38182

# %%
predicted5 = np.loadtxt("BB.txt") 
cm5 = ConfusionMatrix(expected, predicted5)
MyMetrics(cm5)
cm5
# Out:
# FPR: 0.1830259083811893
# Precision: 0.8126604159027814
# Accuracy: 0.8126604159027814
# TPR: 0.4
# F1_score: 0.536117386365109
# Sensitivity: 0.4
# Specificity: 0.8169740916188107
# G-Mean: 0.5716551728511904
# Balance: 0.998823695112957
# AUC: 0.6084870458094053
# Predicted  False  True  __all__
# Actual
# False      30871  6916    37787
# True         237   158      395
# __all__    31108  7074    38182

# %%
predicted6 = np.loadtxt("RUSB.txt") 
cm6 = ConfusionMatrix(expected, predicted6)
MyMetrics(cm6)
cm6
# Out:
# FPR: 0.3212745123984439
# Precision: 0.6759729715572783
# Accuracy: 0.6759729715572783
# TPR: 0.41265822784810124
# F1_score: 0.5124707222581976
# Sensitivity: 0.41265822784810124
# Specificity: 0.678725487601556
# G-Mean: 0.529227415114709
# Balance: 0.9891620628302027
# AUC: 0.5456918577248286
# Predicted  False   True  __all__
# Actual
# False      25647  12140    37787
# True         232    163      395
# __all__    25879  12303    38182

# %%
predicted7 = np.loadtxt("AB.txt") 
cm7 = ConfusionMatrix(expected, predicted7)
# MyMetrics(cm7)
# cm7
cm7.stats()
# Out:
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\stats.py:60: FutureWarning: supplying multiple axes to axis is deprecated and will be removed in a future version.
#   num = df[df > 1].dropna(axis=[0, 1], thresh=1).applymap(lambda n: choose(n, 2)).sum().sum() - np.float64(nis2 * njs2) / n2
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:259: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.TN) / self.NegativeTest)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:302: RuntimeWarning: invalid value encountered in true_divide
#   * (self.TN + self.FP) * (self.TN + self.FN)))
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.FNR) / self.TNR)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:251: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.FN) / self.NegativeTest)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:236: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.TP) / self.PositiveTest)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:267: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.FP) / self.PositiveTest)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:330: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.TPR) / self.FPR)
# OrderedDict([('cm', Predicted    0.0  1.0  __all__
#               Actual
#               0.0        37787    0    37787
#               1.0          395    0      395
#               __all__    38182    0    38182),
#              ('overall',
#               OrderedDict([('Accuracy', 0.9896548111675658),
#                            ('95% CI', (0.9885886831721394, 0.990645445689874)),
#                            ('No Information Rate', 'ToDo'),
#                            ('P-Value [Acc > NIR]', 1.0),
#                            ('Kappa', 0.0),
#                            ("Mcnemar's Test P-Value", 'ToDo')])),
#              ('class',
#               Classes                                      0.0        1.0
#               Population                                 38182      38182
#               P: Condition positive                      37787        395
#               N: Condition negative                        395      37787
#               Test outcome positive                      38182          0
#               Test outcome negative                          0      38182
#               TP: True Positive                          37787          0
#               TN: True Negative                              0      37787
#               FP: False Positive                           395          0
#               FN: False Negative                             0        395
#               TPR: (Sensitivity, hit rate, recall)           1          0
#               TNR=SPC: (Specificity)                         0          1
#               PPV: Pos Pred Value (Precision)         0.989655        NaN
#               NPV: Neg Pred Value                          NaN   0.989655
#               FPR: False-out                                 1          0
#               FDR: False Discovery Rate              0.0103452        NaN
#               FNR: Miss Rate                                 0          1
#               ACC: Accuracy                           0.989655   0.989655
#               F1 score                                0.994801          0
#               MCC: Matthews correlation coefficient        NaN        NaN
#               Informedness                                   0          0
#               Markedness                                   NaN        NaN
#               Prevalence                              0.989655  0.0103452
#               LR+: Positive likelihood ratio                 1        NaN
#               LR-: Negative likelihood ratio               NaN          1
#               DOR: Diagnostic odds ratio                   NaN        NaN
#               FOR: False omission rate                     NaN  0.0103452)])

# %%
predicted1 = np.loadtxt("KNN.txt") 
cm1 = ConfusionMatrix(expected2, predicted1)
MyMetrics(cm1)
cm1
# Out:
# FPR: 0.04420915761121947
# Precision: 0.9477764787580981
# Accuracy: 0.9477764787580981
# TPR: 0.9320431339862472
# F1_score: 0.9398439654435985
# Sensitivity: 0.9320431339862472
# Specificity: 0.9557908423887805
# G-Mean: 0.9438423025990064
# Balance: 0.9999945203140951
# AUC: 0.9439169881875139
# Predicted  False   True  __all__
# Actual
# False      72037   3332    75369
# True        2609  35783    38392
# __all__    74646  39115   113761

# %%
predicted2 = np.loadtxt("DT.txt") 
cm2 = ConfusionMatrix(expected2, predicted2)
MyMetrics(cm2)
cm2
# Out:
# FPR: 0.012697528161445688
# Precision: 0.9789470908307768
# Accuracy: 0.9789470908307768
# TPR: 0.9625442800583455
# F1_score: 0.9706763953603326
# Sensitivity: 0.9625442800583455
# Specificity: 0.9873024718385544
# G-Mean: 0.9748447809552381
# Balance: 0.9999999086593827
# AUC: 0.97492337594845
# Predicted  False   True  __all__
# Actual
# False      74412    957    75369
# True        1438  36954    38392
# __all__    75850  37911   113761

# %%
predicted3 = np.loadtxt("RF.txt") 
cm3 = ConfusionMatrix(expected2, predicted3)
MyMetrics(cm3)
cm3
# Out:
# FPR: 0.025341984104870704
# Precision: 0.9714928666238869
# Accuracy: 0.9714928666238869
# TPR: 0.965279224838508
# F1_score: 0.9683760782847417
# Sensitivity: 0.965279224838508
# Specificity: 0.9746580158951293
# G-Mean: 0.9699572846604579
# Balance: 0.9999994708362755
# AUC: 0.9699686203668187
# Predicted  False   True  __all__
# Actual
# False      73459   1910    75369
# True        1333  37059    38392
# __all__    74792  38969   113761

# %%
# predicted_ = np.loadtxt("AdassPre.txt") 
# expected__ = np.loadtxt("AdassExp.txt") 
# cm_ = ConfusionMatrix(expected_, predicted_)
# MyMetrics(cm_)
# cm_
