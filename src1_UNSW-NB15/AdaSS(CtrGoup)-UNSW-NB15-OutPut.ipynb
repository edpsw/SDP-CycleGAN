# %%
import pandas as pd
from sklearn.metrics import roc_auc_score
  
def Sensitivity(TP,FN):
    sen = TP/(TP + FN)
    return sen

def Specificity(TN,FP):
    spe = TN/(TN + FP)
    return spe

def GMean(sen,spe):
    return (sen * spe) ** 0.5

def FPR(FP,TN):
    return FP/(FP + TN)
  
def Precision(TP, TN, P):
    return (TP + TN) / P
    
def Balance(fpr, pre):
    return 1 - ((fpr**2 + (1-pre)**2)/2) ** 2
    
def AUC(y_true, y_pred):
    return roc_auc_score(y_true, y_pred)

def ACC(TP,TN,P):
    return (TP+TN)/P

def TPR(TP,FN):
    return TP/(TP+FN)

def F1(pre,tpr):
    return 2 * pre * tpr / (pre + tpr)
    
def MyMetrics(cm):
    tab = pd.crosstab(cm._y_true, cm._y_pred)
    TN = tab.reindex()[0][0]
    TP = tab.reindex()[1][1]
    FN = tab.reindex()[0][1]
    FP = tab.reindex()[1][0]
    P = cm.population
    sen = Sensitivity(TP,FN)
    spe = Specificity(TN,FP)
    fpr = FPR(FP,TN)
    pre = Precision(TP, TN, P)
    tpr = TPR(TP,FN)
    acc = ACC(TP,TN,P)
    f1 = F1(pre,tpr)
    
    gmean = GMean(sen,spe)
    balance = Balance(fpr, pre)
    auc = AUC(cm._y_true, cm._y_pred)
    print("FPR:",fpr)
    print("Precision:",pre)
    print("Accuracy:",acc)
    print("TPR:",tpr)
    print("F1_score:",f1)
    
    print("Sensitivity:",sen)
    print("Specificity:",spe)
    print("G-Mean:",gmean)
    print("Balance:", balance)
    print("AUC:", auc)

# %%
import numpy as np 
from pandas_ml import ConfusionMatrix

# %%
expected = np.loadtxt("EXP.txt") 
expected2 = np.loadtxt("EXP2.txt")

# %%
predicted4 = np.loadtxt("EE.txt") 
cm4 = ConfusionMatrix(expected, predicted4)
MyMetrics(cm4)
cm4
# Out:
# FPR: 0.10564926372155288
# Precision: 0.8706510138740662
# Accuracy: 0.8706510138740662
# TPR: 0.8571819841752891
# F1_score: 0.8638640012539928
# Sensitivity: 0.8571819841752891
# Specificity: 0.8943507362784471
# G-Mean: 0.8755691512792065
# Balance: 0.9998054961539365
# AUC: 0.875766360226868
# Predicted  False   True  __all__
# Actual
# False      16702   1973    18675
# True        4693  28167    32860
# __all__    21395  30140    51535

# %%
predicted5 = np.loadtxt("BB.txt") 
cm5 = ConfusionMatrix(expected, predicted5)
MyMetrics(cm5)
cm5
# Out:
# FPR: 0.11378848728246319
# Precision: 0.875599107402736
# Accuracy: 0.875599107402736
# TPR: 0.8695678636640292
# F1_score: 0.8725730636363267
# Sensitivity: 0.8695678636640292
# Specificity: 0.8862115127175368
# G-Mean: 0.8778502445566989
# Balance: 0.9997980275558658
# AUC: 0.877889688190783
# Predicted  False   True  __all__
# Actual
# False      16550   2125    18675
# True        4286  28574    32860
# __all__    20836  30699    51535

# %%
predicted6 = np.loadtxt("RUSB.txt") 
cm6 = ConfusionMatrix(expected, predicted6)
# print(cm6)
# MyMetrics(cm6)
cm6.stats()
# Out:
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\stats.py:60: FutureWarning: supplying multiple axes to axis is deprecated and will be removed in a future version.
#   num = df[df > 1].dropna(axis=[0, 1], thresh=1).applymap(lambda n: choose(n, 2)).sum().sum() - np.float64(nis2 * njs2) / n2
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:259: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.TN) / self.NegativeTest)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:302: RuntimeWarning: invalid value encountered in true_divide
#   * (self.TN + self.FP) * (self.TN + self.FN)))
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.FNR) / self.TNR)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:251: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.FN) / self.NegativeTest)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:236: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.TP) / self.PositiveTest)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:267: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.FP) / self.PositiveTest)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:330: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.TPR) / self.FPR)
# OrderedDict([('cm', Predicted    0.0  1.0  __all__
#               Actual
#               0.0        18675    0    18675
#               1.0        32860    0    32860
#               __all__    51535    0    51535),
#              ('overall',
#               OrderedDict([('Accuracy', 0.3623750848937615),
#                            ('95% CI',
#                             (0.3582231276476577, 0.36654254817974863)),
#                            ('No Information Rate', 'ToDo'),
#                            ('P-Value [Acc > NIR]', 1.0),
#                            ('Kappa', 0.0),
#                            ("Mcnemar's Test P-Value", 'ToDo')])),
#              ('class',
#               Classes                                     0.0       1.0
#               Population                                51535     51535
#               P: Condition positive                     18675     32860
#               N: Condition negative                     32860     18675
#               Test outcome positive                     51535         0
#               Test outcome negative                         0     51535
#               TP: True Positive                         18675         0
#               TN: True Negative                             0     18675
#               FP: False Positive                        32860         0
#               FN: False Negative                            0     32860
#               TPR: (Sensitivity, hit rate, recall)          1         0
#               TNR=SPC: (Specificity)                        0         1
#               PPV: Pos Pred Value (Precision)        0.362375       NaN
#               NPV: Neg Pred Value                         NaN  0.362375
#               FPR: False-out                                1         0
#               FDR: False Discovery Rate              0.637625       NaN
#               FNR: Miss Rate                                0         1
#               ACC: Accuracy                          0.362375  0.362375
#               F1 score                               0.531976         0
#               MCC: Matthews correlation coefficient       NaN       NaN
#               Informedness                                  0         0
#               Markedness                                  NaN       NaN
#               Prevalence                             0.362375  0.637625
#               LR+: Positive likelihood ratio                1       NaN
#               LR-: Negative likelihood ratio              NaN         1
#               DOR: Diagnostic odds ratio                  NaN       NaN
#               FOR: False omission rate                    NaN  0.637625)])

# %%
predicted7 = np.loadtxt("AB.txt") 
cm7 = ConfusionMatrix(expected, predicted7)
MyMetrics(cm7)
cm7
# Out:
# FPR: 0.4898527443105756
# Precision: 0.7846900164936451
# Accuracy: 0.7846900164936451
# TPR: 0.9407181984175289
# F1_score: 0.8556493150464395
# Sensitivity: 0.9407181984175289
# Specificity: 0.5101472556894243
# G-Mean: 0.692751620207273
# Balance: 0.9795060590201072
# AUC: 0.7254327270534767
# Predicted  False   True  __all__
# Actual
# False       9527   9148    18675
# True        1948  30912    32860
# __all__    11475  40060    51535

# %%
predicted1 = np.loadtxt("KNN.txt") 
cm1 = ConfusionMatrix(expected2, predicted1)
MyMetrics(cm1)
cm1
# Out:
# FPR: 0.16457884208277496
# Precision: 0.8661459575482948
# Accuracy: 0.8661459575482948
# TPR: 0.8901464006675264
# F1_score: 0.8779821912424436
# Sensitivity: 0.8901464006675264
# Specificity: 0.835421157917225
# G-Mean: 0.8623497763445614
# Balance: 0.9994936802489033
# AUC: 0.8627837792923757
# Predicted  False   True  __all__
# Actual
# False      43015   8474    51489
# True        7241  58674    65915
# __all__    50256  67148   117404

# %%
predicted2 = np.loadtxt("DT.txt") 
cm2 = ConfusionMatrix(expected2, predicted2)
MyMetrics(cm2)
cm2
# Out:
# FPR: 0.05669172056167337
# Precision: 0.95227590201356
# Accuracy: 0.95227590201356
# TPR: 0.9592808920579534
# F1_score: 0.9557655619775272
# Sensitivity: 0.9592808920579534
# Specificity: 0.9433082794383266
# G-Mean: 0.9512610618464582
# Balance: 0.9999924607451607
# AUC: 0.9512945857481401
# Predicted  False   True  __all__
# Actual
# False      48570   2919    51489
# True        2684  63231    65915
# __all__    51254  66150   117404

# %%
predicted3 = np.loadtxt("RF.txt") 
cm3 = ConfusionMatrix(expected2, predicted3)
MyMetrics(cm3)
cm3
# Out:
# FPR: 0.30286080522053255
# Precision: 0.8552093625430138
# Accuracy: 0.8552093625430138
# TPR: 0.9786846696503072
# F1_score: 0.912790246076801
# Sensitivity: 0.9786846696503072
# Specificity: 0.6971391947794675
# G-Mean: 0.8260020838611876
# Balance: 0.9968252975432106
# AUC: 0.8379119322148872
# Predicted  False   True  __all__
# Actual
# False      35895  15594    51489
# True        1405  64510    65915
# __all__    37300  80104   117404

# %%
############################################
##########################################
predicted_ = np.loadtxt("AdassPre.txt") 
expected_ = np.loadtxt("AdassExp.txt") 
cm_ = ConfusionMatrix(expected_, predicted_)
MyMetrics(cm_)
cm_
# Out:
# FPR: 0.0629833075569303
# Precision: 0.951820086929525
# Accuracy: 0.951820086929525
# TPR: 0.960286716486198
# F1_score: 0.9560346569871373
# Sensitivity: 0.960286716486198
# Specificity: 0.9370166924430697
# G-Mean: 0.9485803513034166
# Balance: 0.9999901146318753
# AUC: 0.9486517044646338
# Predicted  False   True  __all__
# Actual
# False      17570   1181    18751
# True        1302  31483    32785
# __all__    18872  32664    51536

# %%
predicted11 = np.loadtxt("Pre1.txt") 
Exp = np.loadtxt("Exp.txt") 
cm11 = ConfusionMatrix(Exp, predicted11)
MyMetrics(cm11)
cm11
# Out:
# FPR: 0.27764390896921015
# Precision: 0.8307946056078394
# Accuracy: 0.8307946056078394
# TPR: 0.8924223980523432
# F1_score: 0.8605064976154404
# Sensitivity: 0.8924223980523432
# Specificity: 0.7223560910307898
# G-Mean: 0.8028989693637762
# Balance: 0.997205999820922
# AUC: 0.8073892445415665
# Predicted  False   True  __all__
# Actual
# False      13490   5185    18675
# True        3535  29325    32860
# __all__    17025  34510    51535

# %%
predicted22 = np.loadtxt("Pre2.txt") 
cm22 = ConfusionMatrix(Exp, predicted22)
MyMetrics(cm22)
cm22
# Out:
# FPR: 0.1665863453815261
# Precision: 0.8750169787523042
# Accuracy: 0.8750169787523042
# TPR: 0.8986609860012172
# F1_score: 0.8866813892031701
# Sensitivity: 0.8986609860012172
# Specificity: 0.8334136546184739
# G-Mean: 0.8654226346741317
# Balance: 0.9995297224770405
# AUC: 0.8660373203098455
# Predicted  False   True  __all__
# Actual
# False      15564   3111    18675
# True        3330  29530    32860
# __all__    18894  32641    51535

# %%
predicted33 = np.loadtxt("Pre3.txt") 
cm33 = ConfusionMatrix(Exp, predicted33)
MyMetrics(cm33)
cm33
# Out:
# FPR: 0.33745649263721555
# Precision: 0.8719705054817115
# Accuracy: 0.8719705054817115
# TPR: 0.9909920876445526
# F1_score: 0.927679251081163
# Sensitivity: 0.9909920876445526
# Specificity: 0.6625435073627844
# G-Mean: 0.8102933873090596
# Balance: 0.995757533652718
# AUC: 0.8267677975036685
# Predicted  False   True  __all__
# Actual
# False      12373   6302    18675
# True         296  32564    32860
# __all__    12669  38866    51535
