# %%
import numpy as np 
from pandas_ml import ConfusionMatrix

# %%
import pandas as pd
from sklearn.metrics import roc_auc_score
  
def Sensitivity(TP,FN):
    sen = TP/(TP + FN)
    return sen

def Specificity(TN,FP):
    spe = TN/(TN + FP)
    return spe

def GMean(sen,spe):
    return (sen * spe) ** 0.5

def FPR(FP,TN):
    return FP/(FP + TN)
  
def Precision(TP, TN, P):
    return (TP + TN) / P
    
def Balance(fpr, pre):
    return 1 - ((fpr**2 + (1-pre)**2)/2) ** 2
    
def AUC(y_true, y_pred):
    return roc_auc_score(y_true, y_pred)

def ACC(TP,TN,P):
    return (TP+TN)/P

def TPR(TP,FN):
    return TP/(TP+FN)

def F1(pre,tpr):
    return 2 * pre * tpr / (pre + tpr)
    
def MyMetrics(cm):
    tab = pd.crosstab(cm._y_true, cm._y_pred)
    TN = tab.reindex()[0][0]
    TP = tab.reindex()[1][1]
    FN = tab.reindex()[0][1]
    FP = tab.reindex()[1][0]
    P = cm.population
    sen = Sensitivity(TP,FN)
    spe = Specificity(TN,FP)
    fpr = FPR(FP,TN)
    pre = Precision(TP, TN, P)
    tpr = TPR(TP,FN)
    acc = ACC(TP,TN,P)
    f1 = F1(pre,tpr)
    
    gmean = GMean(sen,spe)
    balance = Balance(fpr, pre)
    auc = AUC(cm._y_true, cm._y_pred)
    print("FPR:",fpr)
    print("Precision:",pre)
    print("Accuracy:",acc)
    print("TPR:",tpr)
    print("F1_score:",f1)
    
    print("Sensitivity:",sen)
    print("Specificity:",spe)
    print("G-Mean:",gmean)
    print("Balance:", balance)
    print("AUC:", auc)

# %%
expected = np.loadtxt("EXP.txt") 
expected2 = np.loadtxt("EXP2.txt")

# %%
predicted4 = np.loadtxt("EE.txt") 
cm4 = ConfusionMatrix(expected, predicted4)
MyMetrics(cm4)
cm4
# Out:
# FPR: 0.08288667687595712
# Precision: 0.9165259801163009
# Accuracy: 0.9165259801163009
# TPR: 0.8878504672897196
# F1_score: 0.9019603651990241
# Sensitivity: 0.8878504672897196
# Specificity: 0.9171133231240429
# G-Mean: 0.9023632818844687
# Balance: 0.9999521266557724
# AUC: 0.9024818952068813
# Predicted  False  True  __all__
# Actual
# False       4791   433     5224
# True          12    95      107
# __all__     4803   528     5331

# %%
predicted5 = np.loadtxt("BB.txt") 
cm5 = ConfusionMatrix(expected, predicted5)
MyMetrics(cm5)
cm5
# Out:
# FPR: 0.05972434915773354
# Precision: 0.9379103357719002
# Accuracy: 0.9379103357719002
# TPR: 0.822429906542056
# F1_score: 0.8763822938908187
# Sensitivity: 0.822429906542056
# Specificity: 0.9402756508422665
# G-Mean: 0.8793809274972798
# Balance: 0.9999862280177698
# AUC: 0.8813527786921613
# Predicted  False  True  __all__
# Actual
# False       4912   312     5224
# True          19    88      107
# __all__     4931   400     5331

# %%
predicted6 = np.loadtxt("RUSB.txt") 
cm6 = ConfusionMatrix(expected, predicted6)
# MyMetrics(cm6)
# cm6
cm6.stats()
# Out:
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\stats.py:60: FutureWarning: supplying multiple axes to axis is deprecated and will be removed in a future version.
#   num = df[df > 1].dropna(axis=[0, 1], thresh=1).applymap(lambda n: choose(n, 2)).sum().sum() - np.float64(nis2 * njs2) / n2
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:259: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.TN) / self.NegativeTest)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:302: RuntimeWarning: invalid value encountered in true_divide
#   * (self.TN + self.FP) * (self.TN + self.FN)))
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.FNR) / self.TNR)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:251: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.FN) / self.NegativeTest)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:236: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.TP) / self.PositiveTest)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:267: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.FP) / self.PositiveTest)
# D:\Anaconda3\envs\TF_36aa\lib\site-packages\pandas_ml\confusion_matrix\bcm.py:330: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.TPR) / self.FPR)
# OrderedDict([('cm', Predicted   0.0  1.0  __all__
#               Actual
#               0.0        5224    0     5224
#               1.0         107    0      107
#               __all__    5331    0     5331),
#              ('overall',
#               OrderedDict([('Accuracy', 0.9799287188144813),
#                            ('95% CI',
#                             (0.9757968144075991, 0.9835226716380528)),
#                            ('No Information Rate', 'ToDo'),
#                            ('P-Value [Acc > NIR]', 1.0),
#                            ('Kappa', 0.0),
#                            ("Mcnemar's Test P-Value", 'ToDo')])),
#              ('class',
#               Classes                                      0.0        1.0
#               Population                                  5331       5331
#               P: Condition positive                       5224        107
#               N: Condition negative                        107       5224
#               Test outcome positive                       5331          0
#               Test outcome negative                          0       5331
#               TP: True Positive                           5224          0
#               TN: True Negative                              0       5224
#               FP: False Positive                           107          0
#               FN: False Negative                             0        107
#               TPR: (Sensitivity, hit rate, recall)           1          0
#               TNR=SPC: (Specificity)                         0          1
#               PPV: Pos Pred Value (Precision)         0.979929        NaN
#               NPV: Neg Pred Value                          NaN   0.979929
#               FPR: False-out                                 1          0
#               FDR: False Discovery Rate              0.0200713        NaN
#               FNR: Miss Rate                                 0          1
#               ACC: Accuracy                           0.979929   0.979929
#               F1 score                                0.989863          0
#               MCC: Matthews correlation coefficient        NaN        NaN
#               Informedness                                   0          0
#               Markedness                                   NaN        NaN
#               Prevalence                              0.979929  0.0200713
#               LR+: Positive likelihood ratio                 1        NaN
#               LR-: Negative likelihood ratio               NaN          1
#               DOR: Diagnostic odds ratio                   NaN        NaN
#               FOR: False omission rate                     NaN  0.0200713)])

# %%
predicted7 = np.loadtxt("AB.txt") 
cm7 = ConfusionMatrix(expected, predicted7)
MyMetrics(cm7)
cm7
# Out:
# FPR: 0.006891271056661562
# Precision: 0.9769274057400112
# Accuracy: 0.9769274057400112
# TPR: 0.18691588785046728
# F1_score: 0.3137935397574245
# Sensitivity: 0.18691588785046728
# Specificity: 0.9931087289433385
# G-Mean: 0.43084544769846783
# Balance: 0.9999999159480686
# AUC: 0.5900123083969029
# Predicted  False  True  __all__
# Actual
# False       5188    36     5224
# True          87    20      107
# __all__     5275    56     5331

# %%
predicted1 = np.loadtxt("KNN.txt") 
cm1 = ConfusionMatrix(expected2, predicted1)
MyMetrics(cm1)
cm1
# Out:
# FPR: 0.040931208854116975
# Precision: 0.969031602995304
# Accuracy: 0.969031602995304
# TPR: 0.9888194049649423
# F1_score: 0.9788255073243006
# Sensitivity: 0.9888194049649423
# Specificity: 0.9590687911458831
# G-Mean: 0.9738304941730458
# Balance: 0.9999982649769532
# AUC: 0.9739440980554127
# Predicted  False  True  __all__
# Actual
# False      10052   429    10481
# True          59  5218     5277
# __all__    10111  5647    15758

# %%
predicted2 = np.loadtxt("DT.txt") 
cm2 = ConfusionMatrix(expected2, predicted2)
MyMetrics(cm2)
cm2
# Out:
# FPR: 0.003530197500238527
# Precision: 0.9919406015991877
# Accuracy: 0.9919406015991877
# TPR: 0.9829448550312677
# F1_score: 0.9874222401760189
# Sensitivity: 0.9829448550312677
# Specificity: 0.9964698024997615
# G-Mean: 0.9896842251754667
# Balance: 0.9999999985016831
# AUC: 0.9897073287655147
# Predicted  False  True  __all__
# Actual
# False      10444    37    10481
# True          90  5187     5277
# __all__    10534  5224    15758

# %%
predicted3 = np.loadtxt("RF.txt") 
cm3 = ConfusionMatrix(expected2, predicted3)
MyMetrics(cm3)
cm3
# Out:
# FPR: 0.0029577330407403873
# Precision: 0.9942251554765833
# Accuracy: 0.9942251554765833
# TPR: 0.9886299033541786
# F1_score: 0.9914196350294111
# Sensitivity: 0.9886299033541786
# Specificity: 0.9970422669592596
# G-Mean: 0.9928271753049288
# Balance: 0.9999999995569604
# AUC: 0.992836085156719
# Predicted  False  True  __all__
# Actual
# False      10450    31    10481
# True          60  5217     5277
# __all__    10510  5248    15758

# %%
############################################
##########################################
predicted_ = np.loadtxt("AdassPre.txt") 
expected_ = np.loadtxt("AdassExp.txt") 
cm_ = ConfusionMatrix(expected_, predicted_)
MyMetrics(cm_)
cm_
# Out:
# FPR: 0.002105666156202144
# Precision: 0.9846182704933408
# Accuracy: 0.9846182704933408
# TPR: 0.3364485981308411
# F1_score: 0.5015241009662149
# Sensitivity: 0.3364485981308411
# Specificity: 0.9978943338437979
# G-Mean: 0.5794308843205161
# Balance: 0.9999999854759621
# AUC: 0.6671714659873195
# Predicted  False  True  __all__
# Actual
# False       5213    11     5224
# True          71    36      107
# __all__     5284    47     5331

# %%
predicted11 = np.loadtxt("Pre1.txt") 
Exp = np.loadtxt("Exp.txt") 
cm11 = ConfusionMatrix(Exp, predicted11)
MyMetrics(cm11)
cm11
# Out:
# FPR: 0.005551301684532925
# Precision: 0.9789908084787095
# Accuracy: 0.9789908084787095
# TPR: 0.22429906542056074
# F1_score: 0.3649772646810718
# Sensitivity: 0.22429906542056074
# Specificity: 0.9944486983154671
# G-Mean: 0.47228583891627796
# Balance: 0.9999999442560631
# AUC: 0.6093738818680139
# Predicted  False  True  __all__
# Actual
# False       5195    29     5224
# True          83    24      107
# __all__     5278    53     5331

# %%
predicted22 = np.loadtxt("Pre2.txt") 
cm22 = ConfusionMatrix(Exp, predicted22)
MyMetrics(cm22)
cm22
# Out:
# FPR: 0.00937978560490046
# Precision: 0.9784280622772463
# Accuracy: 0.9784280622772463
# TPR: 0.38317757009345793
# F1_score: 0.5506905648765327
# Sensitivity: 0.38317757009345793
# Specificity: 0.9906202143950995
# G-Mean: 0.616103438261283
# Balance: 0.999999923456789
# AUC: 0.6868988922442787
# Predicted  False  True  __all__
# Actual
# False       5175    49     5224
# True          66    41      107
# __all__     5241    90     5331

# %%
predicted33 = np.loadtxt("Pre3.txt") 
cm33 = ConfusionMatrix(Exp, predicted33)
MyMetrics(cm33)
cm33
# Out:
# FPR: 0.0017228177641653904
# Precision: 0.9849934346276495
# Accuracy: 0.9849934346276495
# TPR: 0.3364485981308411
# F1_score: 0.5015727546622126
# Sensitivity: 0.3364485981308411
# Specificity: 0.9982771822358346
# G-Mean: 0.5795420247999732
# Balance: 0.9999999869851712
# AUC: 0.6673628901833378
# Predicted  False  True  __all__
# Actual
# False       5215     9     5224
# True          71    36      107
# __all__     5286    45     5331
